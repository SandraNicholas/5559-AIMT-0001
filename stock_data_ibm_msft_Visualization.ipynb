# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-01-04  120.315491  120.382408  117.629066  118.489487  104.750328
# 1  2021-01-05  119.512428  121.108986  119.130020  120.592735  106.609711
# 2  2021-01-06  121.319313  126.080307  121.147224  123.604210  109.271996
# 3  2021-01-07  124.321220  124.722755  122.619499  123.317398  109.018448
# 4  2021-01-08  122.915871  123.632889  121.395790  122.877632  108.629677
#
#     Volume Company
# 0  5417443     IBM
# 1  6395872     IBM
# 2  8322708     IBM
# 3  4714740     IBM
# 4  4891305     IBM

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       502 non-null    object
#  1   Open       502 non-null    float64
#  2   High       502 non-null    float64
#  3   Low        502 non-null    float64
#  4   Close      502 non-null    float64
#  5   Adj Close  502 non-null    float64
#  6   Volume     502 non-null    int64
#  7   Company    502 non-null    object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 31.5+ KB

# %%
df['datetime'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       502 non-null    object
#  1   Open       502 non-null    float64
#  2   High       502 non-null    float64
#  3   Low        502 non-null    float64
#  4   Close      502 non-null    float64
#  5   Adj Close  502 non-null    float64
#  6   Volume     502 non-null    int64
#  7   Company    502 non-null    object
#  8   datetime   502 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(1), object(2)
# memory usage: 35.4+ KB

# %%
df_melted = df.melt(id_vars="datetime", value_vars=["High", "Low"], var_name = "stock_values", value_name="y")

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(data=df, x="datetime", y="High", 
            hue="Company", ci = False)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='High'>

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(data=df, x="datetime", y="Low", 
            hue="Company", ci = False)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='Low'>

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(data=df, x="datetime", y="Volume", 
            hue="Company", ci = False)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='Volume'>
